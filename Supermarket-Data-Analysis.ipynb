# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:150%; text-align:left">
#
# <h3 align="center"><font color='#DEB887'>Super Market Data Analysis </font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">

# %% [markdown]
# ![grocery-stores-in-delhi-f-compressed.webp](attachment:grocery-stores-in-delhi-f-compressed.webp)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
# <p style="padding: 10px;
#           color:black;
#           font-size:150%;
#           text-align:center;">
# Goal of  Project :
#     <p style="padding: 9px;
#               color:black;
#               font-size:90%;
#               text-align: center;">
#      To conduct a comprehensive exploratory data analysis of supermarket sales, including sales
#         performance, customer segmentation, product trends, and promotional impact to derive actionable
#         insights.
#
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Source of Data : Kaggle
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Work Flow:
# </p>
# </div>

# %% [markdown]
# - Step 1: Importing the required libraries
# - Step 2: Loading the DataSet
# - Step 3: Basic Understanding of Data
# - Step 4: Preprocessing
# - Step 5: Exploratory Data Analysis (EDA) along with Insights
# - Step 6: Summary of Insights

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 1: Importing the Required Libraries
# </p>
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 2: Loading the Data set
# </p>
# </div>

# %%
df=pd.read_csv("D:\\Desktop\\data sets\\supermarket_sales - Sheet1.csv")

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 3: Basic Understanding of Data
# </p>
# </div>

# %% [markdown]
# ## Preview of data

# %%
df.sample(3)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 65   877-22-3308      A     Yangon        Member    Male
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 268  144-51-6085      A     Yangon        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 65        Health and beauty       15.87        10   7.935  166.635  3/13/2019
# 496  Electronic accessories       63.22         2   6.322  132.762   1/1/2019
# 268      Home and lifestyle       70.74         4  14.148  297.108   1/5/2019
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# 65   16:40         Cash  158.70                 4.761905         7.935     5.8
# 496  15:51         Cash  126.44                 4.761905         6.322     8.5
# 268  16:05  Credit card  282.96                 4.761905        14.148     4.4

# %% [markdown]
# ## How big is the data

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# **observation**:
# - This Dataset has 1000 rows and 17 columns

# %% [markdown]
# ## Basic information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %% [markdown]
# **observation:**
# From above output , all columns are in appropriate type except date and time so we need to convert into datetime for better analysis

# %% [markdown]
# ## Fetching column names

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ##### - Columns Description
#
# - Invoice id: Computer generated sales slip invoice identification number
#
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# - City: Location of supercenters
#
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# - Gender: Gender type of customer
#
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in dollar($)
#
# - Quantity: Number of products purchased by customer
#
# - Tax: 5% tax fee for customer buying
#
# - Total: Total price including tax
#
# - Date: Date of purchase (Record available from January 2019 to March 2019)
#
# - Time: Purchase time (10am to 9pm)
#
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# - COGS: Cost of goods sold excluding tax
#
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
#
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 4: Preprocessing
# </p>
# </div>

# %% [markdown]
# ## Detection of missing values

# %%
df.isnull().sum().to_frame().rename(columns={0:"Missing Value Count"}).T
# Out:
#                      Invoice ID  Branch  City  Customer type  Gender  \
# Missing Value Count           0       0     0              0       0
#
#                      Product line  Unit price  Quantity  Tax 5%  Total  Date  \
# Missing Value Count             0           0         0       0      0     0
#
#                      Time  Payment  cogs  gross margin percentage  \
# Missing Value Count     0        0     0                        0
#
#                      gross income  Rating
# Missing Value Count             0       0

# %% [markdown]
# **OBSERVATION**
#
# There is no missing values in the data, so data seems Simple & Good for Analysis

# %% [markdown]
# ## Detection of Duplicacy

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **OBSERVATION** : There is no Duplicacy in the data

# %% [markdown]
# ## Since the invoice id is irrelavant column so we drop  and also we are dropping the Branch column since each  branch maps to each city as below:
#
# - Mandalay     [B]
# - Naypyitaw    [C]
# - Yangon       [A]

# %%
df.drop(columns=["Invoice ID","Branch"],inplace=True)

# %%
# verifying the result
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# ## Checking the inconsitency or invalid value  in the columns

# %% [markdown]
# **First seggregating the data into object and numeric types and check the inconsitency accordingly**

# %%
df_obj=df.select_dtypes(include="object")
for col in df_obj.columns:
    print(col,"----------------",df[col].unique(),"has",df[col].nunique(),"values","\n\n")
# Out:
# City ---------------- ['Yangon' 'Naypyitaw' 'Mandalay'] has 3 values
#
#
# Customer type ---------------- ['Member' 'Normal'] has 2 values
#
#
# Gender ---------------- ['Female' 'Male'] has 2 values
#
#
# Product line ---------------- ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories'] has 6 values
#
#
# Date ---------------- ['1/5/2019' '3/8/2019' '3/3/2019' '1/27/2019' '2/8/2019' '3/25/2019'
#  '2/25/2019' '2/24/2019' '1/10/2019' '2/20/2019' '2/6/2019' '3/9/2019'
#  '2/12/2019' '2/7/2019' '3/29/2019' '1/15/2019' '3/11/2019' '1/1/2019'
#  '1/21/2019' '3/5/2019' '3/15/2019' '2/17/2019' '3/2/2019' '3/22/2019'
#  '3/10/2019' '1/25/2019' '1/28/2019' '1/7/2019' '3/23/2019' '1/17/2019'
#  '2/2/2019' '3/4/2019' '3/16/2019' '2/27/2019' '2/10/2019' '3/19/2019'
#  '2/3/2019' '3/7/2019' '2/28/2019' '3/27/2019' '1/20/2019' '3/12/2019'
#  '2/15/2019' '3/6/2019' '2/14/2019' '3/13/2019' '1/24/2019' '1/6/2019'
#  '2/11/2019' '1/22/2019' '1/13/2019' '1/9/2019' '1/12/2019' '1/26/2019'
#  '1/23/2019' '2/23/2019' '1/2/2019' '2/9/2019' '3/26/2019' '3/1/2019'
#  '2/1/2019' '3/28/2019' '3/24/2019' '2/5/2019' '1/19/2019' '1/16/2019'
#  '1/8/2019' '2/18/2019' '1/18/2019' '2/16/2019' '2/22/2019' '1/29/2019'
#  '1/4/2019' '3/30/2019' '1/30/2019' '1/3/2019' '3/21/2019' '2/13/2019'
#  '1/14/2019' '3/18/2019' '3/20/2019' '2/21/2019' '1/31/2019' '1/11/2019'
#  '2/26/2019' '3/17/2019' '3/14/2019' '2/4/2019' '2/19/2019'] has 89 values
#
#
# Time ---------------- ['13:08' '10:29' '13:23' '20:33' '10:37' '18:30' '14:36' '11:38' '17:15'
#  '13:27' '18:07' '17:03' '10:25' '16:48' '19:21' '16:19' '11:03' '10:39'
#  '18:00' '15:30' '11:24' '10:40' '12:20' '11:15' '17:36' '19:20' '15:31'
#  '12:17' '19:48' '15:36' '19:39' '12:43' '14:49' '10:12' '10:42' '12:28'
#  '19:15' '17:17' '13:24' '13:01' '18:45' '10:11' '13:03' '20:39' '19:47'
#  '17:24' '15:47' '12:45' '17:08' '10:19' '15:10' '14:42' '15:46' '11:49'
#  '19:01' '11:26' '11:28' '15:55' '20:36' '17:47' '10:55' '13:40' '12:27'
#  '14:35' '16:40' '15:43' '15:01' '10:04' '18:50' '12:46' '18:17' '18:21'
#  '17:04' '14:20' '15:48' '16:24' '18:56' '19:56' '18:37' '10:17' '14:31'
#  '10:23' '20:35' '16:57' '17:55' '19:54' '16:42' '12:09' '20:05' '20:38'
#  '13:11' '10:16' '18:14' '13:22' '11:27' '16:44' '18:19' '14:50' '20:54'
#  '20:19' '10:43' '14:30' '11:32' '10:41' '12:44' '20:07' '20:31' '12:29'
#  '15:26' '20:48' '12:02' '17:26' '19:52' '14:57' '18:44' '13:26' '16:17'
#  '15:57' '13:18' '20:34' '18:36' '14:40' '16:43' '20:59' '15:39' '12:21'
#  '19:25' '13:00' '13:48' '19:57' '10:36' '16:37' '17:11' '15:07' '16:07'
#  '11:56' '18:23' '13:05' '19:40' '13:58' '14:43' '19:18' '16:21' '19:44'
#  '19:42' '15:24' '14:12' '13:32' '16:20' '16:31' '11:36' '19:17' '17:34'
#  '12:04' '17:01' '10:50' '19:16' '16:47' '10:00' '11:51' '15:00' '11:19'
#  '19:46' '19:00' '10:53' '12:50' '20:50' '13:41' '19:08' '20:23' '11:30'
#  '19:30' '18:03' '10:13' '19:58' '10:01' '11:57' '10:02' '14:51' '12:42'
#  '17:38' '20:24' '18:08' '15:53' '15:05' '18:27' '16:55' '12:58' '18:59'
#  '13:44' '13:46' '18:06' '12:38' '15:56' '14:29' '19:14' '10:52' '12:55'
#  '19:28' '13:52' '10:54' '18:31' '18:24' '18:09' '15:16' '17:07' '19:26'
#  '11:20' '16:49' '12:01' '11:25' '18:42' '14:47' '19:43' '14:04' '16:11'
#  '19:06' '15:34' '11:22' '11:23' '10:46' '13:25' '14:53' '19:22' '11:00'
#  '19:24' '17:22' '20:55' '16:05' '13:34' '18:13' '11:44' '15:51' '16:52'
#  '20:52' '16:28' '13:29' '11:09' '15:02' '14:21' '18:01' '13:30' '14:38'
#  '17:37' '17:20' '20:29' '11:46' '13:42' '14:44' '14:16' '15:54' '10:21'
#  '16:46' '20:14' '17:09' '17:43' '19:05' '10:08' '13:12' '20:51' '17:29'
#  '11:34' '18:58' '20:26' '15:08' '13:21' '12:48' '19:53' '19:09' '16:30'
#  '13:07' '18:48' '17:27' '15:59' '11:21' '15:49' '13:02' '20:21' '15:04'
#  '16:10' '12:14' '11:06' '18:22' '19:02' '15:44' '20:01' '13:45' '15:40'
#  '16:58' '11:12' '15:12' '20:37' '17:44' '16:23' '12:12' '19:33' '14:28'
#  '17:54' '12:25' '12:52' '19:50' '15:32' '13:19' '13:37' '14:55' '12:31'
#  '10:26' '20:18' '20:04' '13:38' '17:30' '15:28' '19:07' '18:55' '19:36'
#  '10:57' '17:13' '13:57' '13:53' '16:53' '16:51' '15:37' '20:15' '19:35'
#  '15:42' '14:11' '17:58' '11:02' '15:09' '13:47' '16:59' '14:15' '15:19'
#  '18:33' '12:10' '11:40' '16:54' '15:25' '20:47' '18:20' '11:48' '14:14'
#  '11:17' '12:40' '17:53' '16:36' '10:48' '18:05' '12:07' '19:49' '15:52'
#  '20:46' '10:34' '13:55' '11:43' '16:03' '20:03' '19:41' '18:04' '10:31'
#  '13:28' '17:16' '18:43' '10:30' '20:40' '12:08' '17:45' '10:28' '10:49'
#  '12:34' '18:51' '19:38' '12:32' '10:33' '19:55' '14:33' '13:54' '12:15'
#  '12:37' '15:06' '15:58' '14:03' '16:38' '11:07' '12:23' '14:13' '19:11'
#  '18:53' '14:22' '10:06' '20:08' '12:56' '10:18' '11:45' '16:08' '12:24'
#  '19:51' '18:10' '15:27' '16:04' '14:41' '14:19' '14:08' '11:29' '12:16'
#  '20:00' '15:29' '14:58' '11:52' '17:46' '14:45' '11:39' '13:06' '20:43'
#  '16:34' '13:10' '17:10' '10:22' '19:29' '14:27' '12:22' '11:59' '17:59'
#  '12:51' '13:56' '19:45' '16:18' '18:57' '11:18' '14:06' '20:13' '15:14'
#  '16:06' '12:47' '20:42' '20:10' '14:24' '11:42' '17:49' '15:33' '10:38'
#  '12:39' '14:26' '12:41' '15:20' '16:33' '20:44' '11:16' '12:30' '17:48'
#  '20:30' '13:59' '11:58' '16:50' '18:02' '17:52' '20:32' '16:09' '11:33'
#  '15:15' '20:06' '16:26' '18:38' '16:45' '18:41' '17:12' '14:00' '16:32'
#  '10:10' '10:05' '18:15' '11:01' '15:21' '16:16' '11:05' '19:31' '18:35'
#  '13:51' '12:35' '11:55' '15:11' '14:48' '12:36' '13:35' '15:45' '14:25'
#  '15:18' '10:03' '13:14' '16:35' '20:57' '13:50' '17:35' '17:56' '10:44'
#  '10:09' '10:58' '13:49' '11:10' '13:33' '14:05' '16:27' '15:23' '18:18'
#  '15:17' '19:12'] has 506 values
#
#
# Payment ---------------- ['Ewallet' 'Cash' 'Credit card'] has 3 values

# %%
df_numeric=df.select_dtypes(exclude="object")
for col in df_numeric.columns:
    for i in df[col]:
        if i<0:
            print('Invalid Value')

# %% [markdown]
# **OBSERVATION** : There is no inconsitency and Invalid value in the Dataset

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 5: Exploratory Data Analysis (EDA)
# </p>
# </div>

# %% [markdown]
# #  Feature engineering

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["Time"]=pd.to_datetime(df["Time"])

# %%
df.dtypes
# Out:
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
from datetime import datetime as dt

# %%
df["month"]=df.Date.dt.month_name()
df["day_name"]=df.Date.dt.day_name()
df["day"]=df.Date.dt.day
df["year"]=df.Date.dt.year
df["Hour"]=df.Time.dt.hour

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'month',
#        'day_name', 'day', 'year', 'Hour'],
#       dtype='object')

# %% [markdown]
# # Insights

# %%
df.describe().T
# Out:
#                           count                        mean  \
# Unit price               1000.0                    55.67213
# Quantity                 1000.0                        5.51
# Tax 5%                   1000.0                   15.379369
# Total                    1000.0                  322.966749
# Date                       1000  2019-02-14 00:05:45.600000
# Time                       1000  2024-09-25 15:24:41.880000
# cogs                     1000.0                   307.58738
# gross margin percentage  1000.0                    4.761905
# gross income             1000.0                   15.379369
# Rating                   1000.0                      6.9727
# day                      1000.0                      15.256
# year                     1000.0                      2019.0
# Hour                     1000.0                       14.91
#
#                                          min                  25%  \
# Unit price                             10.08               32.875
# Quantity                                 1.0                  3.0
# Tax 5%                                0.5085             5.924875
# Total                                10.6785           124.422375
# Date                     2019-01-01 00:00:00  2019-01-24 00:00:00
# Time                     2024-09-25 10:00:00  2024-09-25 12:43:00
# cogs                                   10.17             118.4975
# gross margin percentage             4.761905             4.761905
# gross income                          0.5085             5.924875
# Rating                                   4.0                  5.5
# day                                      1.0                  8.0
# year                                  2019.0               2019.0
# Hour                                    10.0                 12.0
#
#                                          50%                  75%  \
# Unit price                             55.23               77.935
# Quantity                                 5.0                  8.0
# Tax 5%                                12.088             22.44525
# Total                                253.848            471.35025
# Date                     2019-02-13 00:00:00  2019-03-08 00:00:00
# Time                     2024-09-25 15:19:00  2024-09-25 18:15:00
# cogs                                  241.76              448.905
# gross margin percentage             4.761905             4.761905
# gross income                          12.088             22.44525
# Rating                                   7.0                  8.5
# day                                     15.0                 23.0
# year                                  2019.0               2019.0
# Hour                                    15.0                 18.0
#
#                                          max         std
# Unit price                             99.96   26.494628
# Quantity                                10.0    2.923431
# Tax 5%                                 49.65   11.708825
# Total                                1042.65  245.885335
# Date                     2019-03-30 00:00:00         NaN
# Time                     2024-09-25 20:59:00         NaN
# cogs                                   993.0   234.17651
# gross margin percentage             4.761905         0.0
# gross income                           49.65   11.708825
# Rating                                  10.0     1.71858
# day                                     31.0    8.693563
# year                                  2019.0         0.0
# Hour                                    20.0    3.186857

# %%
cols=df.describe().T[:-3].index
cols
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df[cols].corr(),annot=True,cmap="rainbow")
# Out:
# <Axes: >

# %% [markdown]
# **observation:**:
#         - There is perfect positive relation found between
#         Total, gross income, tax 5% , cogs
#         - There is sort of positive relation between Total, quantity
#         - There is no correlation between rating and quantity and total

# %%
df.drop(columns=["Tax 5%","cogs","gross income","gross margin percentage"],inplace=True)

# %% [markdown]
# ## Univariate/Bivariate Analysis

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-09-25 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-09-25 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %% [markdown]
# Since the **Total** column is the main column under this EDA so we do the univariate analysis

# %%
plt.figure(figsize=(15,4),facecolor="pink")
plt.subplot(1,2,1)
sns.distplot(df["Total"])
plt.title("distribution of Total Sale")
plt.subplot(1,2,2)
sns.boxplot(df["Total"])
plt.title("outliers in Total Sale");

# %% [markdown]
# **Observation**
#
# Mostly sale of the product is range 10 to 220 dollar & Some products is expensive

# %% [markdown]
# ## Total  and average sale  of the company

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-09-25 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-09-25 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %%
df["Total"].agg(["sum","mean"])
# Out:
# sum     322966.749000
# mean       322.966749
# Name: Total, dtype: float64

# %% [markdown]
# Since the some products are expensive means they are considered as outliers so we find median since the above avg sale does give the genuine insight

# %%
df["Total"].median()
# Out:
# 253.848

# %% [markdown]
# ## Observation:
#
# - Total sale of the company is approx 322966 dollar
# - Average sale of the company is approx 322 dollar

# %% [markdown]
# ### Which city is more crowed ?

# %%
sns.countplot(x="City",data=df,palette="Set2")
plt.title("Crowded City")
# Out:
# Text(0.5, 1.0, 'Crowded City')

# %% [markdown]
# ## **Insight**
#
# yangon is more Crowded City

# %% [markdown]
# ## Total and average sale of each City

# %%
plt.figure(figsize=(15,4),facecolor="pink") 
plt.subplot(1,2,1)
sns.barplot(x="City",y="Total",data=df) #for groupby bar chart we will use
plt.title("Average sale of each City")
plt.subplot(1,2,2)
sns.barplot(x="City",y="Total",data=df,estimator=sum)
plt.title("Total sale of each City")
# Out:
# Text(0.5, 1.0, 'Total sale of each City')

# %% [markdown]
# # Insight :
#
# Although there is no much significant difference  between each city but still we can observe
# **Naypyitaw** is found to be hot selling city

# %% [markdown]
# - The crowded city was yangon but hot selling city found to be Naypitaw
#     There is not much significant difference between three supermarkets in each city but still the city name Naypitaw is found to  be hot selling city

# %% [markdown]
# # Root Cause Analysis of Hot Selling City

# %% [markdown]
# ###  The Highest sale in naypyitaw  on any day

# %%
df_Nay=df[df["City"]=="Naypyitaw"]
df_Nay[df_Nay["Total"]==df_Nay["Total"].max()]
# Out:
#           City Customer type  Gender         Product line  Unit price  \
# 350  Naypyitaw        Member  Female  Fashion accessories        99.3
#
#      Quantity    Total       Date                Time      Payment  Rating  \
# 350        10  1042.65 2019-02-15 2024-09-25 14:53:00  Credit card     6.6
#
#         month day_name  day  year  Hour
# 350  February   Friday   15  2019    14

# %% [markdown]
# ## Insights
#
# - Highest Sale is 1042.65 dollar and Product line is Fashion accessories in the Month of
#   February

# %% [markdown]
# ### The Lowest sale in naypyitaw  on any day

# %%
df_Nay=df[df["City"]=="Naypyitaw"]
df_Nay[df_Nay["Total"]==df_Nay["Total"].min()]
# Out:
#           City Customer type Gender       Product line  Unit price  Quantity  \
# 822  Naypyitaw        Member   Male  Sports and travel       10.17         1
#
#        Total       Date                Time Payment  Rating     month  \
# 822  10.6785 2019-02-07 2024-09-25 14:15:00    Cash     5.9  February
#
#      day_name  day  year  Hour
# 822  Thursday    7  2019    14

# %% [markdown]
# ## Insights
#
# - Lowest Sale is 10.67 dollar and Product line is Sports and travel in the Month of
#   February

# %% [markdown]
# ## Taking factor customer type

# %%
plt.figure(figsize=(14,12))
sns.countplot(x="City",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.barplot(x="City",y="Rating",data=df)
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-09-25 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-09-25 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %%
df[df["Unit price"]==df["Unit price"].max()]
# Out:
#           City Customer type Gender       Product line  Unit price  Quantity  \
# 122   Mandalay        Member   Male  Sports and travel       99.96         9
# 983  Naypyitaw        Normal   Male  Health and beauty       99.96         7
#
#        Total       Date                Time      Payment  Rating    month  \
# 122  944.622 2019-03-09 2024-09-25 17:26:00  Credit card     4.2    March
# 983  734.706 2019-01-23 2024-09-25 10:33:00         Cash     6.1  January
#
#       day_name  day  year  Hour
# 122   Saturday    9  2019    17
# 983  Wednesday   23  2019    10

# %%
df.groupby(["City"])["Product line"].value_counts().to_frame()
# Out:
#                                   count
# City      Product line
# Mandalay  Sports and travel          62
#           Fashion accessories        62
#           Electronic accessories     55
#           Health and beauty          53
#           Home and lifestyle         50
#           Food and beverages         50
# Naypyitaw Food and beverages         66
#           Fashion accessories        65
#           Electronic accessories     55
#           Health and beauty          52
#           Home and lifestyle         45
#           Sports and travel          45
# Yangon    Home and lifestyle         65
#           Electronic accessories     60
#           Sports and travel          59
#           Food and beverages         58
#           Fashion accessories        51
#           Health and beauty          47

# %% [markdown]
# - There is not a specific cause behind the hot selling branch / city this could be due to natural factor

# %% [markdown]
# ### Highest business revenue  month  of the company

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.barplot(x="month",y="Total",data=df,estimator=sum, palette="Set2")
plt.title("Highest business revenue month",fontsize=12,color="Red",fontweight="bold")
plt.subplot(1,2,2)
plt.pie(df.groupby(["month"])["Total"].agg(["sum"])["sum"],labels=df.groupby(["month"])["Total"].agg(["sum"]).index,autopct="%.2f%%",colors=sns.color_palette("Set2"))
plt.title("Hot selling Month of the Company",fontsize=12,color="Red",fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Hot selling Month of the Company')

# %% [markdown]
# ## **Insight**
#
# - January is the Highest Business revenue for the Company with 36.01%

# %% [markdown]
# ## Highest business revenue of city of  each Month and also sale pattern

# %%
plt.figure(figsize=(14,10),facecolor="pink") 
plt.subplot(1,2,1)
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="Set2",hue="month");
plt.title("Average sale of each city in each month",fontsize=15,color="brown",fontweight="bold")
plt.subplot(1,2,2)
sns.boxplot(x="City",y="Total",data=df,palette="Set2",hue="month");
plt.title('Sale pattern of each city in each month',fontsize=15,color="brown",fontweight="bold");

# %% [markdown]
# **Obersvation**
#
# January is the heighest sale of each city

# %% [markdown]
# ## Sale trend of company over the three months

# %%
plt.figure(figsize=(15,4))
sns.relplot(x="Date",y="Total",data=df,kind="line",color="purple",estimator=sum,ci=False) #doudt
plt.xlabel("date")
plt.title("Company Sale trend over the 3 months",fontsize=10,color="red",fontweight="bold")
plt.xticks(rotation=90);

# %% [markdown]
# ## Sale trend of each city

# %%
df_n=df[df["City"]=="Naypyitaw"]
df_y=df[df["City"]=="Yangon"]
df_m=df[df["City"]=="Mandalay"]

# %%
cities=[df_y,df_n,df_m]

# %%
city_name=["Yangon","Naypitaw","Mandalay"]
pos=1
plt.figure(figsize=(16,5))
for city in cities:
    plt.subplot(1,3,pos)
    sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False)
    plt.title(f"the trend of city {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1

# %% [markdown]
# ### Sale  trend of each branch/City at each month

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(18,8))
for city in cities:
    plt.subplot(1,3,pos)
    sns.lineplot(x="Date",y="Total",data=city,estimator=sum,ci=False,hue="month") #doudt ci
    plt.title(f"the trend of city {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1

# %% [markdown]
# ## Hot selling day of the company

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="day",y="Total",data=df,estimator=sum,palette="Set2")
plt.xticks(rotation=90)
plt.title("Hot selling day");

# %% [markdown]
# **Oberservation**
#
# 15th day is the most or hot selling day in a month.

# %% [markdown]
# ## Hot selling day of each branch/city

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(14,15))
for city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.barplot(x="day",y="Total",data=city,estimator=sum,ci=False)
    plt.title(f"the hot selling day of city {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1

# %% [markdown]
# **Oberservation**
#
# 19th day is the most or hot selling day in Yangon in a month.
#
# 23th day is the most or hot selling day in Naypyitaw in a month.
#
# 15th day is the most or hot selling day in Mandalay in a month.

# %% [markdown]
# #### Total weekdays sale and weekends sale

# %%
df["weekday/weekend"]=df["day_name"].apply(lambda x: "weekend" if x=="Saturday" or x=="Sunday" else "weekday")

# %%
sns.barplot(x="weekday/weekend",y="Total",data=df,estimator=sum,palette="pastel");

# %% [markdown]
# **Obeservation**
#
# Weekday is the highest sale.

# %%
df.groupby(["weekday/weekend"])["Total"].sum()
# Out:
# weekday/weekend
# weekday    222388.047
# weekend    100578.702
# Name: Total, dtype: float64

# %%
plt.pie(df.groupby(["weekday/weekend"])["Total"].sum().values,labels=df.groupby(["weekday/weekend"])["Total"].sum().index,autopct="%.2f%%");

# %% [markdown]
# **Observation**
#
# 68.86% Sale generate from Weekday.
#
# 31.14% Sale generate from Weekend.

# %% [markdown]
# ## Weekday and weekend sale of each city

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="pastel",hue="weekday/weekend")
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %% [markdown]
# ## **Insights**
#
# - Weekday is the highest sale of all the city.

# %% [markdown]
# ## Weekday and weekend sale of each branch/City of each month

# %%
df.groupby(["City","month","weekday/weekend"])["Total"].agg(["sum"])
# Out:
#                                            sum
# City      month    weekday/weekend
# Mandalay  February weekday          25964.4525
#                    weekend           8459.8185
#           January  weekday          27634.8870
#                    weekend           9541.1715
#           March    weekday          20898.5805
#                    weekend          13698.7620
# Naypyitaw February weekday          21950.5020
#                    weekend          10984.4805
#           January  weekday          30470.0550
#                    weekend           9964.6260
#           March    weekday          23041.4310
#                    weekend          14157.6120
# Yangon    February weekday          20417.2395
#                    weekend           9442.8810
#           January  weekday          25736.4870
#                    weekend          12944.6415
#           March    weekday          26274.4125
#                    weekend          11384.7090

# %% [markdown]
# ## Find most popular product line of the company/most demanding

# %%
sns.countplot(x="Product line",data=df,palette="pastel")
plt.xticks(rotation=90);

# %% [markdown]
# ## **Insights**
#
# - Fashion Accessories is the most popular product line.
# - Health and Beauty is the Least popular product line.

# %% [markdown]
# ## Most popular product line of the each City

# %%
plt.figure(figsize=(14,11))
sns.countplot(x="City",data=df,hue="Product line",palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# ## Insights
#
# In Yangon
#
# - Most popular product line is Home and Lifestyles
# - Least popular product line is Health and Beauty
#
# In Naypyitaw
#
# - Most popular product line is Food and Beverages
# - Least popular product line is Home and Lifestyles & Sports and Travel
#
# In Mandalay
#
# - Most popular product line is Sports and Travel
# - Least popular product line is Food and Beverages & Home and Lifestyles.

# %% [markdown]
# ## Find the most revenue generating product line of the company

# %%
sns.barplot(x="Product line",y="Total",estimator=sum,data=df,palette="Set2")
plt.xticks(rotation=90);

# %% [markdown]
# ## Insight
#
# - Food and Beverages is the most revenue generating Product line of the company.

# %%
plt.figure(figsize=(10,12))
sns.barplot(x="City",y="Total",estimator=sum,data=df,palette="Set2",hue="Product line",ci=None)
plt.xticks(rotation=90);

# %% [markdown]
# ## Insights
#
# **In city wise**
#
# In Yangon
#
# - Home and Lifestyles is the most revenue generating Product line.
#
#
# In Naypyitaw
#
# - Food and Beverages is the most revenue generating Product line.
#
#
# In Mandalay
#
# - Health and Beauty & Sports and Travel are the most revenue generating Product line.

# %% [markdown]
# ## Find city  and month wise demand of product detail

# %%
df.groupby(["City","month"])["Product line"].value_counts()
# Out:
# City       month     Product line
# Mandalay   February  Fashion accessories       24
#                      Sports and travel         19
#                      Electronic accessories    19
#                      Food and beverages        17
#                      Health and beauty         16
#                      Home and lifestyle        14
#            January   Sports and travel         23
#                      Fashion accessories       21
#                      Food and beverages        19
#                      Electronic accessories    18
#                      Health and beauty         16
#                      Home and lifestyle        14
#            March     Home and lifestyle        22
#                      Health and beauty         21
#                      Sports and travel         20
#                      Electronic accessories    18
#                      Fashion accessories       17
#                      Food and beverages        14
# Naypyitaw  February  Food and beverages        24
#                      Fashion accessories       20
#                      Health and beauty         18
#                      Electronic accessories    17
#                      Home and lifestyle        11
#                      Sports and travel         10
#            January   Fashion accessories       23
#                      Sports and travel         23
#                      Food and beverages        22
#                      Health and beauty         21
#                      Home and lifestyle        18
#                      Electronic accessories    15
#            March     Electronic accessories    23
#                      Fashion accessories       22
#                      Food and beverages        20
#                      Home and lifestyle        16
#                      Health and beauty         13
#                      Sports and travel         12
# Yangon     February  Food and beverages        21
#                      Electronic accessories    18
#                      Fashion accessories       16
#                      Sports and travel         14
#                      Home and lifestyle        13
#                      Health and beauty         12
#            January   Home and lifestyle        27
#                      Sports and travel         24
#                      Electronic accessories    21
#                      Fashion accessories       20
#                      Food and beverages        15
#                      Health and beauty         12
#            March     Home and lifestyle        25
#                      Health and beauty         23
#                      Food and beverages        22
#                      Electronic accessories    21
#                      Sports and travel         21
#                      Fashion accessories       15
# Name: count, dtype: int64

# %% [markdown]
# ### Find the total number of Customers

# %%
print("total customers : ",df["Gender"].count())
sns.countplot(x="Gender",data=df)
# Out:
# total customers :  1000
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# # Total male and female customers in each city

# %%
plt.figure(figsize=(10,12))
sns.countplot(x="City",data=df,hue="Gender")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# ## Which type of customer visiting most in each city

# %%
plt.figure(figsize=(10,12))
sns.countplot(x="City",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# ## Insights
#
# **In city wise**
#
# In Yangon
#
# - Normal type is the most Visiting Customer.
#
#
# In Naypyitaw
#
# - Member type is the most Visiting Customer.
#
#
# In Mandalay
#
# - Normal type is the most Visiting Customer.

# %%
plt.figure(figsize=(10,12))
sns.barplot(x="City",y="Total",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %% [markdown]
# ## Insights
#
# **In city wise**
#
# In Yangon
#
# - Member type customer is the most Revenue generating.
#
#
# In Naypyitaw
#
# - Normal type customer is the most Revenue generating.
#
#
# In Mandalay
#
# - Member type customer is the most Revenue generating.

# %% [markdown]
# ### With different payment mode

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'Rating', 'month',
#        'day_name', 'day', 'year', 'Hour', 'weekday/weekend'],
#       dtype='object')

# %%
df["Payment"].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
plt.pie(df["Payment"].value_counts().values,labels=df["Payment"].value_counts().index,autopct="%.2f%%");

# %% [markdown]
# ## Insights:
#
# - E-wallet is most useful payment mode and followed by Cash.
#
# - Credit Card is the Lowest useful payment mode as compare rest of it.

# %%
df_n["Payment"].value_counts()
# Out:
# Payment
# Cash           124
# Ewallet        106
# Credit card     98
# Name: count, dtype: int64

# %%
df_y["Payment"].value_counts()
# Out:
# Payment
# Ewallet        126
# Cash           110
# Credit card    104
# Name: count, dtype: int64

# %%
df_m["Payment"].value_counts()
# Out:
# Payment
# Ewallet        113
# Cash           110
# Credit card    109
# Name: count, dtype: int64

# %%
cities
# Out:
# [       City Customer type  Gender            Product line  Unit price  \
#  0    Yangon        Member  Female       Health and beauty       74.69
#  2    Yangon        Normal    Male      Home and lifestyle       46.33
#  3    Yangon        Member    Male       Health and beauty       58.22
#  4    Yangon        Normal    Male       Sports and travel       86.31
#  6    Yangon        Member  Female  Electronic accessories       68.84
#  ..      ...           ...     ...                     ...         ...
#  990  Yangon        Normal  Female      Food and beverages       56.56
#  992  Yangon        Normal    Male  Electronic accessories       58.03
#  997  Yangon        Member    Male      Food and beverages       31.84
#  998  Yangon        Normal    Male      Home and lifestyle       65.82
#  999  Yangon        Member  Female     Fashion accessories       88.34
#
#       Quantity     Total       Date                Time      Payment  Rating  \
#  0           7  548.9715 2019-01-05 2024-09-25 13:08:00      Ewallet     9.1
#  2           7  340.5255 2019-03-03 2024-09-25 13:23:00  Credit card     7.4
#  3           8  489.0480 2019-01-27 2024-09-25 20:33:00      Ewallet     8.4
#  4           7  634.3785 2019-02-08 2024-09-25 10:37:00      Ewallet     5.3
#  6           6  433.6920 2019-02-25 2024-09-25 14:36:00      Ewallet     5.8
#  ..        ...       ...        ...                 ...          ...     ...
#  990         5  296.9400 2019-03-22 2024-09-25 19:06:00  Credit card     4.5
#  992         2  121.8630 2019-03-10 2024-09-25 20:46:00      Ewallet     8.8
#  997         1   33.4320 2019-02-09 2024-09-25 13:22:00         Cash     7.7
#  998         1   69.1110 2019-02-22 2024-09-25 15:33:00         Cash     4.1
#  999         7  649.2990 2019-02-18 2024-09-25 13:28:00         Cash     6.6
#
#          month  day_name  day  year  Hour
#  0     January  Saturday    5  2019    13
#  2       March    Sunday    3  2019    13
#  3     January    Sunday   27  2019    20
#  4    February    Friday    8  2019    10
#  6    February    Monday   25  2019    14
#  ..        ...       ...  ...   ...   ...
#  990     March    Friday   22  2019    19
#  992     March    Sunday   10  2019    20
#  997  February  Saturday    9  2019    13
#  998  February    Friday   22  2019    15
#  999  February    Monday   18  2019    13
#
#  [340 rows x 16 columns],
#            City Customer type  Gender            Product line  Unit price  \
#  1    Naypyitaw        Normal  Female  Electronic accessories       15.28
#  5    Naypyitaw        Normal    Male  Electronic accessories       85.39
#  7    Naypyitaw        Normal  Female      Home and lifestyle       73.56
#  20   Naypyitaw        Member    Male  Electronic accessories       86.04
#  34   Naypyitaw        Member  Female      Food and beverages       99.42
#  ..         ...           ...     ...                     ...         ...
#  983  Naypyitaw        Normal    Male       Health and beauty       99.96
#  984  Naypyitaw        Normal    Male  Electronic accessories       96.37
#  988  Naypyitaw        Member    Male  Electronic accessories       82.34
#  994  Naypyitaw        Member  Female  Electronic accessories       60.95
#  995  Naypyitaw        Normal    Male       Health and beauty       40.35
#
#       Quantity     Total       Date                Time  Payment  Rating  \
#  1           5   80.2200 2019-03-08 2024-09-25 10:29:00     Cash     9.6
#  5           7  627.6165 2019-03-25 2024-09-25 18:30:00  Ewallet     4.1
#  7          10  772.3800 2019-02-24 2024-09-25 11:38:00  Ewallet     8.0
#  20          5  451.7100 2019-02-25 2024-09-25 11:24:00  Ewallet     4.8
#  34          4  417.5640 2019-02-06 2024-09-25 10:42:00  Ewallet     7.5
#  ..        ...       ...        ...                 ...      ...     ...
#  983         7  734.7060 2019-01-23 2024-09-25 10:33:00     Cash     6.1
#  984         7  708.3195 2019-01-09 2024-09-25 11:40:00     Cash     6.0
#  988        10  864.5700 2019-03-29 2024-09-25 19:12:00  Ewallet     4.3
#  994         1   63.9975 2019-02-18 2024-09-25 11:40:00  Ewallet     5.9
#  995         1   42.3675 2019-01-29 2024-09-25 13:46:00  Ewallet     6.2
#
#          month   day_name  day  year  Hour
#  1       March     Friday    8  2019    10
#  5       March     Monday   25  2019    18
#  7    February     Sunday   24  2019    11
#  20   February     Monday   25  2019    11
#  34   February  Wednesday    6  2019    10
#  ..        ...        ...  ...   ...   ...
#  983   January  Wednesday   23  2019    10
#  984   January  Wednesday    9  2019    11
#  988     March     Friday   29  2019    19
#  994  February     Monday   18  2019    11
#  995   January    Tuesday   29  2019    13
#
#  [328 rows x 16 columns],
#           City Customer type  Gender            Product line  Unit price  \
#  9    Mandalay        Member  Female      Food and beverages       54.84
#  10   Mandalay        Member  Female     Fashion accessories       14.48
#  11   Mandalay        Member    Male  Electronic accessories       25.51
#  15   Mandalay        Member  Female       Sports and travel       93.72
#  19   Mandalay        Normal  Female      Home and lifestyle       40.30
#  ..        ...           ...     ...                     ...         ...
#  987  Mandalay        Member    Male       Health and beauty       62.00
#  989  Mandalay        Member    Male       Health and beauty       75.37
#  991  Mandalay        Normal  Female       Sports and travel       76.60
#  993  Mandalay        Normal    Male     Fashion accessories       17.49
#  996  Mandalay        Normal  Female      Home and lifestyle       97.38
#
#       Quantity     Total       Date                Time      Payment  Rating  \
#  9           3   172.746 2019-02-20 2024-09-25 13:27:00  Credit card     5.9
#  10          4    60.816 2019-02-06 2024-09-25 18:07:00      Ewallet     4.5
#  11          4   107.142 2019-03-09 2024-09-25 17:03:00         Cash     6.8
#  15          6   590.436 2019-01-15 2024-09-25 16:19:00         Cash     4.5
#  19          2    84.630 2019-03-11 2024-09-25 15:30:00      Ewallet     4.4
#  ..        ...       ...        ...                 ...          ...     ...
#  987         8   520.800 2019-01-03 2024-09-25 19:08:00  Credit card     6.2
#  989         8   633.108 2019-01-28 2024-09-25 15:46:00  Credit card     8.4
#  991        10   804.300 2019-01-24 2024-09-25 18:10:00      Ewallet     6.0
#  993        10   183.645 2019-02-22 2024-09-25 18:35:00      Ewallet     6.6
#  996        10  1022.490 2019-03-02 2024-09-25 17:16:00      Ewallet     4.4
#
#          month   day_name  day  year  Hour
#  9    February  Wednesday   20  2019    13
#  10   February  Wednesday    6  2019    18
#  11      March   Saturday    9  2019    17
#  15    January    Tuesday   15  2019    16
#  19      March     Monday   11  2019    15
#  ..        ...        ...  ...   ...   ...
#  987   January   Thursday    3  2019    19
#  989   January     Monday   28  2019    15
#  991   January   Thursday   24  2019    18
#  993  February     Friday   22  2019    18
#  996     March   Saturday    2  2019    17
#
#  [332 rows x 16 columns]]

# %%
cities[0]
# Out:
#        City Customer type  Gender            Product line  Unit price  \
# 0    Yangon        Member  Female       Health and beauty       74.69
# 2    Yangon        Normal    Male      Home and lifestyle       46.33
# 3    Yangon        Member    Male       Health and beauty       58.22
# 4    Yangon        Normal    Male       Sports and travel       86.31
# 6    Yangon        Member  Female  Electronic accessories       68.84
# ..      ...           ...     ...                     ...         ...
# 990  Yangon        Normal  Female      Food and beverages       56.56
# 992  Yangon        Normal    Male  Electronic accessories       58.03
# 997  Yangon        Member    Male      Food and beverages       31.84
# 998  Yangon        Normal    Male      Home and lifestyle       65.82
# 999  Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity     Total       Date                Time      Payment  Rating  \
# 0           7  548.9715 2019-01-05 2024-09-25 13:08:00      Ewallet     9.1
# 2           7  340.5255 2019-03-03 2024-09-25 13:23:00  Credit card     7.4
# 3           8  489.0480 2019-01-27 2024-09-25 20:33:00      Ewallet     8.4
# 4           7  634.3785 2019-02-08 2024-09-25 10:37:00      Ewallet     5.3
# 6           6  433.6920 2019-02-25 2024-09-25 14:36:00      Ewallet     5.8
# ..        ...       ...        ...                 ...          ...     ...
# 990         5  296.9400 2019-03-22 2024-09-25 19:06:00  Credit card     4.5
# 992         2  121.8630 2019-03-10 2024-09-25 20:46:00      Ewallet     8.8
# 997         1   33.4320 2019-02-09 2024-09-25 13:22:00         Cash     7.7
# 998         1   69.1110 2019-02-22 2024-09-25 15:33:00         Cash     4.1
# 999         7  649.2990 2019-02-18 2024-09-25 13:28:00         Cash     6.6
#
#         month  day_name  day  year  Hour
# 0     January  Saturday    5  2019    13
# 2       March    Sunday    3  2019    13
# 3     January    Sunday   27  2019    20
# 4    February    Friday    8  2019    10
# 6    February    Monday   25  2019    14
# ..        ...       ...  ...   ...   ...
# 990     March    Friday   22  2019    19
# 992     March    Sunday   10  2019    20
# 997  February  Saturday    9  2019    13
# 998  February    Friday   22  2019    15
# 999  February    Monday   18  2019    13
#
# [340 rows x 16 columns]

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.pie(df_y["Payment"].value_counts().values,labels=df_y["Payment"].value_counts().index,autopct="%.2f%%")
plt.title("% of customers based on \nmode of payment of city yangon")
plt.subplot(1,3,2)
plt.pie(df_m["Payment"].value_counts().values,labels=df_m["Payment"].value_counts().index,autopct="%.2f%%")
plt.title("% of customers based on \n mode of payment of city mandalay")
plt.subplot(1,3,3)
plt.pie(df_n["Payment"].value_counts().values,labels=df_n["Payment"].value_counts().index,autopct="%.2f%%")
plt.title("% of customers based on\n mode of payment of city naypayitaw");

# %% [markdown]
# ## Insights
#
# **In city wise**
#
# In Yangon
#
# - E-wallet is most use payment mode
# - Cash is Least use payment mode
#
# In Naypyitaw
#
# - E-wallet is most use payment mode
# - Credit Card is Least use payment mode
#
#
# In Mandalay
#
# - Cash is most use payment mode
# - Credit Card is Least use payment mode

# %% [markdown]
# # Who contributed most in each city

# %%
plt.figure(figsize=(10,12))
sns.barplot(x="City",y="Total",data=df,estimator=sum,hue="Gender")
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %% [markdown]
# ### Find the peak time of Customers visit at supermarket

# %% [markdown]
# ##### Add hour for better analysis

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'Rating', 'month',
#        'day_name', 'day', 'year', 'Hour', 'weekday/weekend'],
#       dtype='object')

# %%
df["Hour"]
# Out:
# 0      13
# 1      10
# 2      13
# 3      20
# 4      10
#        ..
# 995    13
# 996    17
# 997    13
# 998    15
# 999    13
# Name: Hour, Length: 1000, dtype: int32

# %%
plt.figure(figsize=(17,9))
sns.relplot(x="Hour",y="Total",data=df,estimator=sum,kind="line",ci=None);

# %% [markdown]
# ## Peak time for each city

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(14,15))
for city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.lineplot(x="Hour",y="Total",data=city,estimator=sum,ci=False)
    plt.title(f" hourly sale trend of {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1

# %%
city_name
# Out:
# ['Yangon', 'Naypyitaw', 'Mandalay']

# %%
city=['Yangon', 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(25,15))
for i in cities:
    plt.subplot(3,1,pos)
    sns.lineplot(x="Hour",y="Total",data=i,estimator=sum,ci=None,hue="Product line")
    plt.title(f"peak time of branch {city[pos-1]}")
    plt.xticks(list(range(10,21)))
    pos=pos+1

# %% [markdown]
# # Rating

# %%
sns.distplot(df["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.boxplot(df["Rating"])
# Out:
# <Axes: >

# %%
# there is no outliers in it so we can find mean easily

# %% [markdown]
# ### Find Highest,lowest and average rating to the company

# %%
df["Rating"].agg(["max","min","mean"])
# Out:
# max     10.0000
# min      4.0000
# mean     6.9727
# Name: Rating, dtype: float64

# %% [markdown]
# ### How many customers had given 10 ratings

# %%
print(len(df[df["Rating"]==10.0]), "customers had given 10 rating")
print((len(df[df["Rating"]==10.0])*100)/df["Rating"].count(),"% customers had given 10 rating")
# Out:
# 5 customers had given 10 rating
# 0.5 % customers had given 10 rating

# %%
df["Rating"].unique()
len(df["Rating"].unique())
# Out:
# 61

# %%
len(df["Rating"].value_counts())
df["Rating"].value_counts()
# Out:
# Rating
# 6.0     26
# 6.6     24
# 4.2     22
# 9.5     22
# 6.5     21
#         ..
# 4.0     11
# 5.3     11
# 8.3     11
# 4.6      8
# 10.0     5
# Name: count, Length: 61, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x="Rating",data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %% [markdown]
# ### How many customers had given 4 ratings ?

# %%
print(len(df[df["Rating"]==4.0]), "customers had given 4 rating")
print((len(df[df["Rating"]==4.0])*100)/df["Rating"].count(),"% customers had given 10 rating")
# Out:
# 11 customers had given 4 rating
# 1.1 % customers had given 10 rating

# %% [markdown]
# ### How many customers had given below or equals 5 ratings ?

# %%
 print(len(df[df["Rating"]<=5.0]), "customers had given below rating")
print((len(df[df["Rating"]<=5.0])*100)/df["Rating"].count(),"% customers had given below 5 rating")
# Out:
# 174 customers had given below rating
# 17.4 % customers had given below 5 rating

# %% [markdown]
# ### Find  Ratings given by customers at each City

# %%
df.groupby(["City"])["Rating"].agg(["max","min","mean"]) #show as well by sublot individually
# Out:
#             max  min      mean
# City
# Mandalay   10.0  4.0  6.818072
# Naypyitaw  10.0  4.0  7.072866
# Yangon     10.0  4.0  7.027059

# %% [markdown]
# ## rating wrt each product

# %%
df.groupby(["Product line"])["Rating"].agg(["max","min","mean"])
# Out:
#                          max  min      mean
# Product line
# Electronic accessories  10.0  4.0  6.924706
# Fashion accessories      9.9  4.0  7.029213
# Food and beverages       9.9  4.0  7.113218
# Health and beauty       10.0  4.0  7.003289
# Home and lifestyle       9.9  4.1  6.837500
# Sports and travel       10.0  4.0  6.916265

# %%
df.groupby(["City","Product line"])["Rating"].agg(["max","min","mean"])
# Out:
#                                    max  min      mean
# City      Product line
# Mandalay  Electronic accessories  10.0  4.0  7.116364
#           Fashion accessories      9.9  4.1  6.722581
#           Food and beverages       9.9  4.0  6.994000
#           Health and beauty        9.9  4.0  7.100000
#           Home and lifestyle       9.8  4.1  6.516000
#           Sports and travel       10.0  4.1  6.509677
# Naypyitaw Electronic accessories   9.8  4.1  6.747273
#           Fashion accessories      9.9  4.0  7.440000
#           Food and beverages       9.9  4.0  7.080303
#           Health and beauty        9.9  4.1  6.998077
#           Home and lifestyle       9.8  4.3  7.060000
#           Sports and travel       10.0  4.0  7.028889
# Yangon    Electronic accessories   9.9  4.3  6.911667
#           Fashion accessories      9.9  4.0  6.878431
#           Food and beverages       9.9  4.0  7.253448
#           Health and beauty       10.0  4.2  6.900000
#           Home and lifestyle       9.9  4.1  6.930769
#           Sports and travel        9.9  4.1  7.257627

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 6: Summary of Insights
# </p>
# </div>

# %% [markdown]
# - **Top Performing Product Line**
#
# - **Total Sales and Revenue Trend**
#
# - **City-wise Sales Distribution**
#
# - **Top Performing Cities**
#
# - **Preferred Payment Methods**
#
# -  **Customer Rating Analysis**
#
# - **Category-wise Revenue**
#
# - **Customer Type Analysis**
#
# - **Time-based Sales Trend**
